# %% [markdown]
# # DATA SCIENCE INTERN AT LETSGROWMORE
# **LGMVIP OCT-2021**
#
# **Task2: Image To Pencil Image (Beginner Level)**
#
# **Author: SIMEEN ASIF PAWASKAR**

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing libraries
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#loading the image
image=cv2.imread('babypanda.jpg')

# %% [markdown]
# **Reading the Image**

# %%
im = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,7))
plt.imshow(im)
plt.title("ORIGINAL IMAGE")
plt.axis("off")
plt.show()

# %% [markdown]
# **Converting the Original Image to GrayScale**

# %%
img_gray = cv2.cvtColor(im , cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,6))
plt.imshow(img_gray,cmap="gray")
plt.title("GRAYSCALE IMAGE")
plt.axis("off")
plt.show()

# %% [markdown]
# **Inverting the New Image**

# %%
img_invert = cv2.bitwise_not(img_gray)
plt.figure(figsize=(10,6))
plt.imshow(img_invert,cmap="gray")
plt.title("INVERTED IMAGE")
plt.axis("off")
plt.show()

# %% [markdown]
#  **Blurring the Image Using Gaussian Function**

# %%
img_blur = cv2.GaussianBlur(img_invert,(21,21),0)
plt.figure(figsize=(10,6))
plt.imshow(img_blur,cmap="gray")
plt.title("BLURRED IMAGE")
plt.axis("off")
plt.show()

# %% [markdown]
# **Converting Image to Pencil Image**

# %%
img_pencil = cv2.divide(img_gray,255-img_blur,scale=255)
plt.figure(figsize=(10,6))
plt.imshow(img_pencil,cmap="gray")
plt.title("FINAL SKETCH IMAGE")
plt.axis("off")
plt.show()
